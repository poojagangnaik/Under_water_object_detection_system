# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.175 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.1/112.6 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# '1 Event Doc.rar'
# '2011-06-09 15.14.11.jpg'
#  20120126_123133.jpg
# '8051 Lab Kit-1.jpg'
# 'Adkraft Box.pdf'
# 'Adkraft Jar.jpg'
# 'Basic Electronics - Level 1 Day 2.mp4'
#  CatDogDataset
# 'Colab Notebooks'
#  DSC00170.JPG
#  DSC01055.JPG
# 'Embedded Development & Internship Interactive Session (2024-07-21 11:02 GMT+5:30)'
# 'Embedded Development & Internship Interactive Session (2024-07-21 11:02 GMT+5:30) (1)'
# 'Embedded Development & Internship Interactive Session (2024-07-21 11:02 GMT+5:30) – Chat transcript (1).gdrive'
# 'Embedded Development & Internship Interactive Session (2024-07-21 11:02 GMT+5:30) – Chat transcript.gdrive'
# 'Google Photos'
#  GSTR3B_29BCFPK9562D1ZC_082024.pdf
# 'Internship - Python - AI ML.pptx'
# 'Internship Short.rar'
# 'MPLAB_IDE_8_83 (used in Mar 24 both 16F877A and 18F458).rar'
# 'My Drive'
# ...

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

#!unrar /content/gdrive/YoloImgTrainVal.rar
# !unrar x "/content/gdrive/MyDrive/YoloImgTrainVal.rar" "/{HOME}/datasets/"
# Out:
# mkdir: cannot create directory ‘/content/datasets’: File exists
# /content/datasets
#
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from /content/gdrive/MyDrive/YoloImgTrainVal.rar
#
# Creating    //content/datasets/YoloImgTrainVal                        OK
# Creating    //content/datasets/YoloImgTrainVal/train                  OK
# Creating    //content/datasets/YoloImgTrainVal/train/images           OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolo11n.pt data=/content/datasets/YoloImgTrainVal/data.yaml epochs=20 imgsz=240 plots=True
# Out:
# /content
# Ultralytics 8.3.175 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
print("Project End")
